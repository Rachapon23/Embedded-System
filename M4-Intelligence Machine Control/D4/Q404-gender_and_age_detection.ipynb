# %%
# single pic
# import cv2
# import math
# import argparse

# my_name = "B6216184 Mr.Rachapon Pongkittisak"
# img = cv2.imread("./image/girl1.jpg")

    
# def highlightFace(net, frame, conf_threshold=0.7):
#     img = frame.copy()
#     h = img.shape[0]
#     w = img.shape[1]
#     blob = cv2.dnn.blobFromImage(img, 1.0, (300,300), [104,117,123], True, False)
    
#     net.setInput(blob)
#     detections = net.forward()
#     faceBoxes = []
#     for i in range(detections.shape[2]):
#         confidence = detections[0,0,i,2]
#         if(confidence > conf_threshold):
#             x1 = int(detections[0,0,i,3] * w)
#             y1 = int(detections[0,0,i,4] * h)
#             x2 = int(detections[0,0,i,5] * w)
#             y2 = int(detections[0,0,i,6] * h)
#             faceBoxes.append([x1,y1,x2,y2])
#             cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,0), int(round(h/150)))
#     return img, faceBoxes


# faceProto = "./data/opencv_face_detector.pbtxt"
# faceModel = "./data/opencv_face_detector_uint8.pb"
# ageProto = "./data/age_deploy.prototxt"
# ageModel = "./data/age_net.caffemodel"
# genderProto = "./data/gender_deploy.prototxt"
# genderModel = "./data/gender_net.caffemodel"

# MODEL_MEAN_VALUES = (78.4263377603, 87.7689143744, 114.895847746)
# ageList = ["(0-2)", "(4-6)", "(8-12)", "(15-20)", "(25-32)", "(38-43)", "(48-53)", "(60-100)"]
# genderList = ["Male", "Female"]

# faceNet = cv2.dnn.readNet(faceModel, faceProto)
# ageNet = cv2.dnn.readNet(ageModel, ageProto)
# genderNet = cv2.dnn.readNet(genderModel, genderProto)

# padding = 20

# frame = img.copy()
# resultImg, faceBoxes = highlightFace(faceNet, frame)

# if(not faceBoxes):
#     print("No face detected")
# for faceBox in faceBoxes:
#     face = frame[max(0,faceBox[1]-padding):min(faceBox[3]+padding, frame.shape[0]-1),
#                  max(0,faceBox[0]-padding):min(faceBox[2]+padding, frame.shape[1]-1)]

#     blob = cv2.dnn.blobFromImage(face, 1.0, (227, 227), MODEL_MEAN_VALUES, swapRB=False)
#     genderNet.setInput(blob)
#     genderPreds = genderNet.forward()
#     gender = genderList[genderPreds[0].argmax()]
#     print(f"Gender: {gender}")

#     ageNet.setInput(blob)
#     agePreds = ageNet.forward()
#     age = ageList[agePreds[0].argmax()]
#     print(f"Age: {age[1:-1]} years")

#     cv2.putText(resultImg, f"{gender}, {age}", (faceBox[0], faceBox[1]-10),
#                 cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2, cv2.LINE_AA)
#     cv2.imshow(my_name+" >> Detecting age and gender", resultImg)

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# multiple pic
# import cv2
# import os
# import math
# import argparse

# my_name = "B6216184 Mr.Rachapon Pongkittisak"
# img = cv2.imread("./image/girl1.jpg")

# def load_img_from_folder(folder):
#     images = []
#     for filename in os.listdir(folder):
#         img = cv2.imread(os.path.join(folder, filename))
#         if(img is not None):
#             images.append(img)
#     return images

# def highlightFace(net, frame, conf_threshold=0.7):
#     img = frame.copy()
#     h = img.shape[0]
#     w = img.shape[1]
#     blob = cv2.dnn.blobFromImage(img, 1.0, (300,300), [104,117,123], True, False)
    
#     net.setInput(blob)
#     detections = net.forward()
#     faceBoxes = []
#     for i in range(detections.shape[2]):
#         confidence = detections[0,0,i,2]
#         if(confidence > conf_threshold):
#             x1 = int(detections[0,0,i,3] * w)
#             y1 = int(detections[0,0,i,4] * h)
#             x2 = int(detections[0,0,i,5] * w)
#             y2 = int(detections[0,0,i,6] * h)
#             faceBoxes.append([x1,y1,x2,y2])
#             cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,0), int(round(h/150)))
#     return img, faceBoxes


# faceProto = "./data/opencv_face_detector.pbtxt"
# faceModel = "./data/opencv_face_detector_uint8.pb"
# ageProto = "./data/age_deploy.prototxt"
# ageModel = "./data/age_net.caffemodel"
# genderProto = "./data/gender_deploy.prototxt"
# genderModel = "./data/gender_net.caffemodel"

# MODEL_MEAN_VALUES = (78.4263377603, 87.7689143744, 114.895847746)
# ageList = ["(0-2)", "(4-6)", "(8-12)", "(15-20)", "(25-32)", "(38-43)", "(48-53)", "(60-100)"]
# genderList = ["Male", "Female"]

# faceNet = cv2.dnn.readNet(faceModel, faceProto)
# ageNet = cv2.dnn.readNet(ageModel, ageProto)
# genderNet = cv2.dnn.readNet(genderModel, genderProto)

# padding = 20

# images = load_img_from_folder("./image_face_detection")
# for i in range(len(images)):
#     frame = images[i].copy()
#     resultImg, faceBoxes = highlightFace(faceNet, frame)

#     if(not faceBoxes):
#         print("No face detected")
#     print(f"Picture {i} ")
#     for faceBox in faceBoxes:
#         face = frame[max(0,faceBox[1]-padding):min(faceBox[3]+padding, frame.shape[0]-1),
#                      max(0,faceBox[0]-padding):min(faceBox[2]+padding, frame.shape[1]-1)]

#         blob = cv2.dnn.blobFromImage(face, 1.0, (227, 227), MODEL_MEAN_VALUES, swapRB=False)
#         genderNet.setInput(blob)
#         genderPreds = genderNet.forward()
#         gender = genderList[genderPreds[0].argmax()]
#         print(f"Gender: {gender}\t",end="")

#         ageNet.setInput(blob)
#         agePreds = ageNet.forward()
#         age = ageList[agePreds[0].argmax()]
#         print(f"Age: {age[1:-1]} years")

#         cv2.putText(resultImg, f"{gender}, {age}", (faceBox[0], faceBox[1]-10),
#                     cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2, cv2.LINE_AA)
#         cv2.imshow(my_name+" >> Detecting age and gender "+str(i), resultImg)
#     print()
        
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# webcam
import cv2
import math
import argparse

my_name = "B6216184 Mr.Rachapon Pongkittisak"
    
def highlightFace(net, frame, conf_threshold=0.7):
    img = frame.copy()
    h = img.shape[0]
    w = img.shape[1]
    blob = cv2.dnn.blobFromImage(img, 1.0, (300,300), [104,117,123], True, False)
    
    net.setInput(blob)
    detections = net.forward()
    faceBoxes = []
    for i in range(detections.shape[2]):
        confidence = detections[0,0,i,2]
        if(confidence > conf_threshold):
            x1 = int(detections[0,0,i,3] * w)
            y1 = int(detections[0,0,i,4] * h)
            x2 = int(detections[0,0,i,5] * w)
            y2 = int(detections[0,0,i,6] * h)
            faceBoxes.append([x1,y1,x2,y2])
            cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,0), int(round(h/150)))
    return img, faceBoxes


faceProto = "./data/opencv_face_detector.pbtxt"
faceModel = "./data/opencv_face_detector_uint8.pb"
ageProto = "./data/age_deploy.prototxt"
ageModel = "./data/age_net.caffemodel"
genderProto = "./data/gender_deploy.prototxt"
genderModel = "./data/gender_net.caffemodel"

MODEL_MEAN_VALUES = (78.4263377603, 87.7689143744, 114.895847746)
ageList = ["(0-2)", "(4-6)", "(8-12)", "(15-20)", "(25-32)", "(38-43)", "(48-53)", "(60-100)"]
genderList = ["Male", "Female"]

faceNet = cv2.dnn.readNet(faceModel, faceProto)
ageNet = cv2.dnn.readNet(ageModel, ageProto)
genderNet = cv2.dnn.readNet(genderModel, genderProto)

padding = 20
cap = cv2.VideoCapture(0)

while(cap.isOpened()):
    if(cv2.waitKey(1) == ord("q")):
            break
    ret, frame = cap.read()
    resultImg, faceBoxes = highlightFace(faceNet, frame)

    if(not faceBoxes):
        print("No face detected")
    for faceBox in faceBoxes:
        face = frame[max(0,faceBox[1]-padding):min(faceBox[3]+padding, frame.shape[0]-1),
                     max(0,faceBox[0]-padding):min(faceBox[2]+padding, frame.shape[1]-1)]

        blob = cv2.dnn.blobFromImage(face, 1.0, (227, 227), MODEL_MEAN_VALUES, swapRB=False)
        genderNet.setInput(blob)
        genderPreds = genderNet.forward()
        gender = genderList[genderPreds[0].argmax()]
        print(f"Gender:{gender}")

        ageNet.setInput(blob)
        agePreds = ageNet.forward()
        age = ageList[agePreds[0].argmax()]
        print(f"Age: {age[1:-1]} years")

        cv2.putText(resultImg, f"{gender}, {age}", (faceBox[0], faceBox[1]-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2, cv2.LINE_AA)
        cv2.imshow(my_name+" >> Detecting age and gender", resultImg)
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 15-20 years
# Gender:Male
# Age: 15-20 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 8-12 years
# Gender:Male
# Age: 15-20 years
# ...

# %%
# video
# import cv2
# import math
# import argparse

# my_name = "B6216184 Mr.Rachapon Pongkittisak"
    
# def highlightFace(net, frame, conf_threshold=0.7):
#     img = frame.copy()
#     h = img.shape[0]
#     w = img.shape[1]
#     blob = cv2.dnn.blobFromImage(img, 1.0, (300,300), [104,117,123], True, False)
    
#     net.setInput(blob)
#     detections = net.forward()
#     faceBoxes = []
#     for i in range(detections.shape[2]):
#         confidence = detections[0,0,i,2]
#         if(confidence > conf_threshold):
#             x1 = int(detections[0,0,i,3] * w)
#             y1 = int(detections[0,0,i,4] * h)
#             x2 = int(detections[0,0,i,5] * w)
#             y2 = int(detections[0,0,i,6] * h)
#             faceBoxes.append([x1,y1,x2,y2])
#             cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,0), int(round(h/150)))
#     return img, faceBoxes


# faceProto = "./data/opencv_face_detector.pbtxt"
# faceModel = "./data/opencv_face_detector_uint8.pb"
# ageProto = "./data/age_deploy.prototxt"
# ageModel = "./data/age_net.caffemodel"
# genderProto = "./data/gender_deploy.prototxt"
# genderModel = "./data/gender_net.caffemodel"

# MODEL_MEAN_VALUES = (78.4263377603, 87.7689143744, 114.895847746)
# ageList = ["(0-2)", "(4-6)", "(8-12)", "(15-20)", "(25-32)", "(38-43)", "(48-53)", "(60-100)"]
# genderList = ["Male", "Female"]

# faceNet = cv2.dnn.readNet(faceModel, faceProto)
# ageNet = cv2.dnn.readNet(ageModel, ageProto)
# genderNet = cv2.dnn.readNet(genderModel, genderProto)

# padding = 20
# cap = cv2.VideoCapture("./video/escalator.mp4")

# while(cap.isOpened()):
#     if(cv2.waitKey(1) == ord("q")):
#             break
#     ret, frame = cap.read()
#     resultImg, faceBoxes = highlightFace(faceNet, frame)

#     if(not faceBoxes):
#         print("No face detected")
#     for faceBox in faceBoxes:
#         face = frame[max(0,faceBox[1]-padding):min(faceBox[3]+padding, frame.shape[0]-1),
#                      max(0,faceBox[0]-padding):min(faceBox[2]+padding, frame.shape[1]-1)]

#         blob = cv2.dnn.blobFromImage(face, 1.0, (227, 227), MODEL_MEAN_VALUES, swapRB=False)
#         genderNet.setInput(blob)
#         genderPreds = genderNet.forward()
#         gender = genderList[genderPreds[0].argmax()]
#         print(f"Gender:{gender}")

#         ageNet.setInput(blob)
#         agePreds = ageNet.forward()
#         age = ageList[agePreds[0].argmax()]
#         print(f"Age: {age[1:-1]} years")

#         cv2.putText(resultImg, f"{gender}, {age}", (faceBox[0], faceBox[1]-10),
#                     cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2, cv2.LINE_AA)
#         cv2.imshow(my_name+" >> Detecting age and gender", resultImg)
        
# cap.release()
# cv2.destroyAllWindows()
